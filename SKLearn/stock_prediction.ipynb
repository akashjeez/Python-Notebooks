# %%
import pandas, numpy
from datetime import datetime, timedelta
import pandas_datareader.data as web
from sklearn import linear_model, svm
from sklearn.model_selection import train_test_split

# %%
### Predicts Stock Prices using Machine Learning Models.

start_date = datetime.now() - timedelta(days = 365)

df = web.DataReader('AAPL', 'yahoo', start_date, datetime.now())
df.tail(10)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-02-11  323.899994  318.709991  323.600006  319.609985  23580800.0
# 2020-02-12  327.220001  321.470001  321.470001  327.200012  28432600.0
# 2020-02-13  326.220001  323.350006  324.190002  324.869995  23686900.0
# 2020-02-14  325.980011  322.850006  324.739990  324.950012  20028400.0
# 2020-02-18  319.750000  314.609985  315.359985  319.000000  38132800.0
# 2020-02-19  324.570007  320.000000  320.000000  323.619995  23496000.0
# 2020-02-20  324.649994  318.209991  322.630005  320.299988  25141500.0
# 2020-02-21  320.450012  310.500000  318.619995  313.049988  32388500.0
# 2020-02-24  304.179993  289.230011  297.260010  298.179993  55548800.0
# 2020-02-25  302.529999  286.130005  300.950012  288.079987  57566400.0
#
#              Adj Close
# Date
# 2020-02-11  319.609985
# 2020-02-12  327.200012
# 2020-02-13  324.869995
# 2020-02-14  324.950012
# 2020-02-18  319.000000
# 2020-02-19  323.619995
# 2020-02-20  320.299988
# 2020-02-21  313.049988
# 2020-02-24  298.179993
# 2020-02-25  288.079987

# %%
## Get the Adjusted Close Price.
df = df[['Adj Close']]
df.tail()
# Out:
#              Adj Close
# Date
# 2020-02-19  323.619995
# 2020-02-20  320.299988
# 2020-02-21  313.049988
# 2020-02-24  298.179993
# 2020-02-25  288.079987

# %%
## Predicting N days out into the Future.
forecast_out = 30

## Create Another Column (Target or Dependent Variable) shifted N units up.
df['Prediction'] = df[['Adj Close']].shift(-forecast_out)
df.tail()
# Out:
#              Adj Close  Prediction
# Date
# 2020-02-19  323.619995         NaN
# 2020-02-20  320.299988         NaN
# 2020-02-21  313.049988         NaN
# 2020-02-24  298.179993         NaN
# 2020-02-25  288.079987         NaN

# %%
## Create Independent Dataset X

## Convert DataFrame to Numpy Array.
X = numpy.array(df.drop(['Prediction'], axis = 1))

## Remove Last N Rows.
X = X[ : - forecast_out]

X
# Out:
# array([[172.07766724],
#        [172.61068726],
#        [170.91291809],
#        [172.7093811 ],
#        [173.57803345],
#        [173.26216125],
#        [172.26522827],
#        [170.27131653],
#        [170.67602539],
#        [176.58860779],
#        [178.57266235],
#        [179.36231995],
#        [181.35621643],
#        [183.71533203],
#        [185.59080505],
#        [184.12005615],
#        [185.72898865],
#        [192.56942749],
#        [188.58164978],
#        [186.30148315],
#        [184.37667847],
#        [186.03497314],
#        [186.28173828],
#        [187.49586487],
#        [188.76921082],
#        [191.51329041],
#        [192.82611084],
#        [193.16168213],
#        [194.45475769],
#        [197.51470947],
#        [196.92247009],
#        [198.02798462],
#        [196.37957764],
#        [196.3006134 ],
#        [196.65596008],
#        [196.67570496],
#        [200.50558472],
#        [201.22615051],
#        [201.88749695],
#        [204.79936218],
#        [204.48350525],
#        [202.62780762],
#        [201.66046143],
#        [201.96646118],
#        [198.07736206],
#        [207.80010986],
#        [206.44779968],
#        [209.01422119],
#        [205.78646851],
#        [200.23907471],
#        [200.27853394],
#        [198.12670898],
#        [195.38197327],
#        [184.02648926],
#        [186.93966675],
#        [189.17906189],
#        [188.34672546],
#        [187.27658081],
#        [181.42047119],
#        [184.89846802],
#        [181.11328125],
#        [178.02174377],
#        [177.33804321],
#        [176.6047821 ],
#        [175.76252747],
#        [176.67414856],
#        [173.47360229],
#        [171.71972656],
#        [178.00192261],
#        [180.87545776],
#        [183.53103638],
#        [188.41607666],
#        [190.82392883],
#        [193.03358459],
#        [192.41925049],
#        [192.3795929 ],
#        [190.98246765],
#        [192.12197876],
#        [196.64039612],
#        [196.06568909],
#        [197.64118958],
#        [196.96737671],
#        [196.76921082],
#        [193.78666687],
#        [197.97808838],
#        [197.91864014],
#        [196.11521912],
#        [199.71214294],
#        [200.88136292],
#        [202.54605103],
#        [202.36767578],
#        [198.19607544],
#        [199.40496826],
#        [201.3768158 ],
#        [199.91030884],
#        [201.44618225],
#        [203.33876038],
#        [202.63522339],
#        [201.49571228],
#        [203.78465271],
#        [200.74264526],
#        [205.33042908],
#        [206.93563843],
#        [206.76721191],
#        [205.13226318],
#        [205.84568787],
#        [207.76799011],
#        [206.87619019],
#        [211.09736633],
#        [206.52937317],
#        [202.15960693],
#        [191.57698059],
#        [195.20361328],
#        [197.2250061 ],
#        [201.57498169],
#        [199.91392517],
#        [199.40664673],
#        [207.85121155],
#        [201.664505  ],
#        [200.65991211],
#        [205.39442444],
#        [209.22381592],
#        [209.23376465],
#        [211.5015564 ],
#        [211.32252502],
#        [201.55509949],
#        [205.38447571],
#        [203.06695557],
#        [204.42962646],
#        [207.89097595],
#        [207.62243652],
#        [204.59869385],
#        [208.07003784],
#        [212.13812256],
#        [212.1182251 ],
#        [213.02336121],
#        [215.53981018],
#        [222.39292908],
#        [221.89559937],
#        [217.57884216],
#        [218.72268677],
#        [219.5184021 ],
#        [221.57733154],
#        [219.77702332],
#        [216.56428528],
#        [217.54899597],
#        [216.51455688],
#        [219.84663391],
#        [218.71273804],
#        [217.64848328],
#        [222.77088928],
#        [223.38757324],
#        [217.78771973],
#        [219.63775635],
#        [225.7946167 ],
#        [225.84434509],
#        [223.19859314],
#        [225.81451416],
#        [228.85812378],
#        [234.94535828],
#        [234.60717773],
#        [234.06013489],
#        [233.11520386],
#        [234.02033997],
#        [235.14430237],
#        [239.22233582],
#        [238.67529297],
#        [241.8780365 ],
#        [242.27589417],
#        [245.25984192],
#        [247.71661377],
#        [241.98744202],
#        [241.95761108],
#        [247.42816162],
#        [254.45037842],
#        [256.12136841],
#        [255.75337219],
#        [255.86276245],
#        [258.81573486],
#        [259.52407837],
#        [261.57919312],
#        [261.3397522 ],
#        [263.84381104],
#        [262.01815796],
#        [265.13076782],
#        [266.46759033],
#        [265.65951538],
#        [262.56686401],
#        [261.38964844],
#        [261.16018677],
#        [265.73931885],
#        [263.66424561],
#        [267.20584106],
#        [266.61724854],
#        [263.5345459 ],
#        [258.83572388],
#        [261.12026978],
#        [264.95117188],
#        [270.06903076],
#        [266.2880249 ],
#        [267.84432983],
#        [270.12890625],
#        [270.81726074],
#        [274.49853516],
#        [279.19735718],
#        [279.74609375],
#        [279.07766724],
#        [279.35699463],
#        [278.77838135],
#        [283.32757568],
#        [283.59692383],
#        [289.22360229],
#        [289.11383057],
#        [290.82977295],
#        [292.95471191],
#        [299.6388855 ],
#        [296.72576904],
#        [299.09014893],
#        [297.68353271],
#        [302.47213745],
#        [308.89691162],
#        [309.59521484]])

# %%
## Create Dependent Dataset y

## Convert DataFrame to Numpy Array.
y = numpy.array(df['Prediction'])

## Get all y values Except Last N Rows.
y = y[ : - forecast_out]

y
# Out:
# array([196.92247009, 198.02798462, 196.37957764, 196.3006134 ,
#        196.65596008, 196.67570496, 200.50558472, 201.22615051,
#        201.88749695, 204.79936218, 204.48350525, 202.62780762,
#        201.66046143, 201.96646118, 198.07736206, 207.80010986,
#        206.44779968, 209.01422119, 205.78646851, 200.23907471,
#        200.27853394, 198.12670898, 195.38197327, 184.02648926,
#        186.93966675, 189.17906189, 188.34672546, 187.27658081,
#        181.42047119, 184.89846802, 181.11328125, 178.02174377,
#        177.33804321, 176.6047821 , 175.76252747, 176.67414856,
#        173.47360229, 171.71972656, 178.00192261, 180.87545776,
#        183.53103638, 188.41607666, 190.82392883, 193.03358459,
#        192.41925049, 192.3795929 , 190.98246765, 192.12197876,
#        196.64039612, 196.06568909, 197.64118958, 196.96737671,
#        196.76921082, 193.78666687, 197.97808838, 197.91864014,
#        196.11521912, 199.71214294, 200.88136292, 202.54605103,
#        202.36767578, 198.19607544, 199.40496826, 201.3768158 ,
#        199.91030884, 201.44618225, 203.33876038, 202.63522339,
#        201.49571228, 203.78465271, 200.74264526, 205.33042908,
#        206.93563843, 206.76721191, 205.13226318, 205.84568787,
#        207.76799011, 206.87619019, 211.09736633, 206.52937317,
#        202.15960693, 191.57698059, 195.20361328, 197.2250061 ,
#        201.57498169, 199.91392517, 199.40664673, 207.85121155,
#        201.664505  , 200.65991211, 205.39442444, 209.22381592,
#        209.23376465, 211.5015564 , 211.32252502, 201.55509949,
#        205.38447571, 203.06695557, 204.42962646, 207.89097595,
#        207.62243652, 204.59869385, 208.07003784, 212.13812256,
#        212.1182251 , 213.02336121, 215.53981018, 222.39292908,
#        221.89559937, 217.57884216, 218.72268677, 219.5184021 ,
#        221.57733154, 219.77702332, 216.56428528, 217.54899597,
#        216.51455688, 219.84663391, 218.71273804, 217.64848328,
#        222.77088928, 223.38757324, 217.78771973, 219.63775635,
#        225.7946167 , 225.84434509, 223.19859314, 225.81451416,
#        228.85812378, 234.94535828, 234.60717773, 234.06013489,
#        233.11520386, 234.02033997, 235.14430237, 239.22233582,
#        238.67529297, 241.8780365 , 242.27589417, 245.25984192,
#        247.71661377, 241.98744202, 241.95761108, 247.42816162,
#        254.45037842, 256.12136841, 255.75337219, 255.86276245,
#        258.81573486, 259.52407837, 261.57919312, 261.3397522 ,
#        263.84381104, 262.01815796, 265.13076782, 266.46759033,
#        265.65951538, 262.56686401, 261.38964844, 261.16018677,
#        265.73931885, 263.66424561, 267.20584106, 266.61724854,
#        263.5345459 , 258.83572388, 261.12026978, 264.95117188,
#        270.06903076, 266.2880249 , 267.84432983, 270.12890625,
#        270.81726074, 274.49853516, 279.19735718, 279.74609375,
#        279.07766724, 279.35699463, 278.77838135, 283.32757568,
#        283.59692383, 289.22360229, 289.11383057, 290.82977295,
#        292.95471191, 299.6388855 , 296.72576904, 299.09014893,
#        297.68353271, 302.47213745, 308.89691162, 309.59521484,
#        316.20953369, 311.93966675, 310.60284424, 314.49359131,
#        317.97537231, 315.82046509, 316.94781494, 318.47418213,
#        317.55633545, 308.21850586, 316.93780518, 323.572052  ,
#        323.10317993, 308.77719116, 307.92919922, 318.09506226,
#        320.68893433, 324.44000244, 320.02999878, 321.54998779,
#        319.60998535, 327.20001221, 324.86999512, 324.95001221,
#        319.        , 323.61999512, 320.29998779, 313.04998779,
#        298.17999268, 288.07998657])

# %%
## Split the Dataset into 80 % Training and 20 % Testing.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

## Create & Train the Support Vector Machine (Regressor).
# Radio Basis Kernal

svr_rbf = svm.SVR(kernel = 'rbf', C = 1e3, gamma = 0.1)
svr_rbf.fit(X_train, y_train)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
## Tesing the Model.
# Score return theCo-efficicent of Determination R^2 of the Prediction.

svm_confidence = svr_rbf.score(X_test, y_test)

print("Score using SVM : {} %".format( round(svm_confidence * 100, 2) ))
# Out:
# Score using SVM : 91.53 %

# %%
## Split the Dataset into 80 % Training and 20 % Testing.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

## Create & Train the Linear Regression Model.

lr_model = linear_model.LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
## Tesing the Model.
# Score return th eCo-efficicent of Determination R^2 of the Prediction.

lr_confidence = lr_model.score(X_test, y_test)

print("Score using Linear Regression : {} %".format( round(lr_confidence * 100, 2) ))
# Out:
# Score using Linear Regression : 90.52 %

# %%
X_forecast = numpy.array(df.drop(['Prediction'], 1))[-forecast_out : ]

X_forecast
# Out:
# array([[316.20953369],
#        [311.93966675],
#        [310.60284424],
#        [314.49359131],
#        [317.97537231],
#        [315.82046509],
#        [316.94781494],
#        [318.47418213],
#        [317.55633545],
#        [308.21850586],
#        [316.93780518],
#        [323.572052  ],
#        [323.10317993],
#        [308.77719116],
#        [307.92919922],
#        [318.09506226],
#        [320.68893433],
#        [324.44000244],
#        [320.02999878],
#        [321.54998779],
#        [319.60998535],
#        [327.20001221],
#        [324.86999512],
#        [324.95001221],
#        [319.        ],
#        [323.61999512],
#        [320.29998779],
#        [313.04998779],
#        [298.17999268],
#        [288.07998657]])

# %%
## Print Linear Regression Model Predictions for Next N Days.
lr_prediction = lr_model.predict(X_forecast)
print("\n Lienar Regression Model Prediction for Next N Days: \n {}".format(lr_prediction))

## Print Support Vector Regressor Model Predictions for Next N Days.
svm_prediction = svr_rbf.predict(X_forecast)
print("\n Support Vector Regressor Model Prediction for Next N Days: \n {}".format(svm_prediction))
# Out:
#  Lienar Regression Model Prediction for Next N Days:
#  [358.00445058 352.66937575 350.99905482 355.86043037 360.21081469
#  357.51832065 358.92691157 360.83406308 359.68724029 348.01989321
#  358.91440466 367.20370354 366.61786149 348.71795429 347.65841296
#  360.3603638  363.60133167 368.28818242 362.77801083 364.67719299
#  362.25321624 371.73673452 368.82544579 368.92542482 361.49105725
#  367.26360707 363.11535427 354.05668967 335.47706232 322.85739782]
#
#  Support Vector Regressor Model Prediction for Next N Days:
#  [261.02943942 258.90883058 272.29930305 258.94587211 261.49471528
#  260.75005498 261.338172   261.51964231 261.45443407 304.10604571
#  261.33544336 261.5394131  261.53941252 299.45095935 305.29937161
#  261.50247624 261.53913759 261.53941331 261.53831661 261.53937377
#  261.53689327 261.53941333 261.53941332 261.53941332 261.53152589
#  261.53941313 261.53878347 256.67141764 321.52654415 301.22986218]
